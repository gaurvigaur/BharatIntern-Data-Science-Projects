# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic= pd.read_csv('train.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.shape
# Out:
# (891, 12)

# %%
sns.countplot(x='Survived', data=titanic, edgecolor='purple', palette='pink')
plt.show()

# %%
sns.countplot(x='Survived', hue='Sex', data=titanic, palette='hot', edgecolor='Black')
plt.show()

# %%
sns.countplot(x='Survived', hue='Pclass', data=titanic, palette='PuBu', edgecolor='Blue')
plt.show()

# %%
titanic['Age'].plot.hist(edgecolor='pink', color='brown')
plt.show()

# %%
titanic['Fare'].plot.hist(edgecolor='brown', bins=20, figsize=(10,5), color='pink')
plt.show()

# %%
sns.countplot(x='SibSp', data=titanic, palette='summer', edgecolor='Green')
plt.show()

# %%
titanic['Parch'].plot.hist(color='green', edgecolor='cyan')
# Out:
# <Axes: ylabel='Frequency'>

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(titanic.isnull(), cmap='summer')
plt.show()

# %%
sns.boxplot(x='Pclass', y='Age', data=titanic)
plt.show()

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.drop('Cabin', axis=1, inplace=True)

# %%
titanic.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# ...

# %%
titanic.dropna(inplace=True)

# %%
sns.heatmap(titanic.isnull(), cbar=True)
plt.show()

# %%
titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
titanic.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# ...

# %%
pd.get_dummies(titanic['Sex']).head()
# Out:
#    female  male
# 0       0     1
# 1       1     0
# 2       1     0
# 3       1     0
# 4       0     1

# %%
sex=pd.get_dummies(titanic['Sex'], drop_first=True)
sex.head(5)
# Out:
#    male
# 0     1
# 1     0
# 2     0
# 3     0
# 4     1

# %%
embark=pd.get_dummies(titanic['Embarked'])
embark.head(5)
# Out:
#    C  Q  S
# 0  0  0  1
# 1  1  0  0
# 2  0  0  1
# 3  0  0  1
# 4  0  0  1

# %%
embark=pd.get_dummies(titanic['Embarked'], drop_first=True)
embark.head(6)
# Out:
#    Q  S
# 0  0  1
# 1  0  0
# 2  0  1
# 3  0  1
# 4  0  1
# 6  0  1

# %%
Pcl=pd.get_dummies(titanic['Pclass'], drop_first=True)
Pcl.head(5)
# Out:
#    2  3
# 0  0  1
# 1  0  0
# 2  0  1
# 3  0  0
# 4  0  1

# %%
titanic=pd.concat([titanic, sex, embark, Pcl], axis=1)
titanic.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Embarked  male  Q  S  2  3
# 0      0         A/5 21171   7.2500        S     1  0  1  0  1
# 1      0          PC 17599  71.2833        C     0  0  0  0  0
# ...

# %%
titanic.drop(['Name', 'PassengerId', 'Pclass', 'Ticket', 'Sex', 'Embarked'], axis=1, inplace=True)
titanic.head(5)
# Out:
#    Survived   Age  SibSp  Parch     Fare  male  Q  S  2  3
# 0         0  22.0      1      0   7.2500     1  0  1  0  1
# 1         1  38.0      1      0  71.2833     0  0  0  0  0
# 2         1  26.0      0      0   7.9250     0  0  1  0  1
# 3         1  35.0      1      0  53.1000     0  0  1  0  0
# 4         0  35.0      0      0   8.0500     1  0  1  0  1

# %%
X=titanic.drop('Survived', axis=1)
y=titanic['Survived']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.33, random_state=4)

# %%
from sklearn.linear_model import LogisticRegression
lm=LogisticRegression(max_iter=1000)

# %%
X_test.columns = X_train.columns.astype(str)
lm.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
prediction=lm.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
classification_report(y_test, prediction)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.81      0.88      0.84       145\n           1       0.77      0.67      0.71        90\n\n    accuracy                           0.80       235\n   macro avg       0.79      0.77      0.78       235\nweighted avg       0.79      0.80      0.79       235\n'

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, prediction )
# Out:
# array([[127,  18],
#        [ 30,  60]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, prediction)
# Out:
# 0.7957446808510639
